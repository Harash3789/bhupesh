# %% [markdown]
# | *Category*     | *Details*                                                                                      |
# | ---------------- | ------------------------------------------------------------------------------------------------ |
# | *Definition*   | A Python 2D plotting library used for creating static, interactive, and animated visualizations. |
# | *Main Module*  | matplotlib.pyplot                                                                              |
# | *Developed In* | Python                                                                                           |
# | *Common Use*   | Data visualization in data science, machine learning, and research                               |

# %% [markdown]
# | *Plot Type*  | *Description*                                                              |
# | -------------- | ---------------------------------------------------------------------------- |
# | Line Plot      | Shows trends over time or continuous data using lines.                       |
# | Bar Plot       | Displays categorical data with rectangular bars.                             |
# | Histogram      | Shows distribution of a dataset by grouping into bins.                       |
# | Scatter Plot   | Plots points for two variables to show relationships or clusters.            |
# | Pie Chart      | Represents data as slices of a pie to show proportions.                      |
# | Box Plot       | Shows data distribution with median, quartiles, and

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsh\appdata\roaming\python\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsh\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsh\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\harsh\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: C:\Users\harsh\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import sys

# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\harsh\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\harsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsh\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\harsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsh\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\harsh\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x= [1,2,3,4,5]

y=[2,4,5,8,10]



plt.plot(x,y)

plt.show()

# %%
xpoint =np.array([0,6])
ypoint =np.array([0,250])
plt.plot(xpoint,ypoint,'o')
plt.show()

# %%
xpoint = np.array([1,8,5,9])
plt.plot(xpoint,marker='o')
plt.show()

# %%
xpoint = np.array([1,8,5,9])
plt.plot(xpoint,marker='o',ms=30)
plt.show()

# %%
xpoint = np.array([1,8,5,9])
plt.plot(xpoint,marker='*',ms=30)
plt.show()

# %%
xpoint = np.array([1,8,5,9])
plt.plot(xpoint,marker='*',ms=30,mec='r')
plt.show()

# %%
xpoint = np.array([1,8,5,9])
plt.plot(xpoint,marker='*',ms=30,mec='r',mfc='pink')
plt.show()

# %%
x= np.array([1,8,5,7])
plt.plot(x,ls= 'dotted')
plt.show()

# %%
x= np.array([1,8,5,7])
plt.plot(x,ls= 'dashed')
plt.show()

# %%
x= np.array([1,8,5,7])
plt.plot(x,linewidth=5)
plt.show()

# %%
x=np.array([1,5,8,4])
y=np.array([2,3,7,5])
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x=np.array([1,8,5,7])
plt.title("hm aaj matplotlib pd rhe hai")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x,linewidth=5)
plt.grid()
plt.show()

# %%
x=np.plt.plot(x)array([1,5,8,4])
y=np.array([2,3,7,5])
plt.plot(y)
plt.grid()
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([1,4,8,6])
plt.subplot(1,2,1)
plt.plot(x,y)

x =np.array([1,2,3,4])
y =np.array([1,5,9,4])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
np.array([1,2,3,4,5])
np.array([1,5,6,2,8])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([1,5,6,2,8])
plt.scatter(x,y)
x1=np.array([1,5,8,4])
y1=np.array([2,3,9,5])
plt.scatter(x1,y1)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([1,5,6,2,8])
c=np.array(['red','green','blue','yellow','black'])
plt.scatter(x,y,c=c)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([1,5,6,2,8])
c=np.array(['red','green','blue','yellow','black'])
plt.scatter(x,y,c=c, alpha=0.5)   ### alpha= visiblity
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c,alpha=0.5,cmap='coolwarm' )
plt.colorbar()
plt.show()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_20312\3890919328.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, s = sizes, c = c,alpha=0.5,cmap='coolwarm' )

# %% [markdown]
# bar plot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y,color='green')
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y,color="green",width=0.1)
plt.show()

# %% [markdown]
# #Hist plot

# %%
x=np.random.normal(170,10,250)

# %%
x
# Out:
# array([149.44061431, 179.26827681, 175.82155136, 167.64811418,
#        154.98569305, 169.11923622, 172.4161369 , 163.71504244,
#        137.53739473, 165.0181384 , 164.31201973, 156.86033907,
#        157.62212143, 160.87467595, 171.25684374, 166.00872557,
#        169.53276345, 166.82874673, 169.54005114, 168.65442115,
#        192.14241158, 163.25267477, 182.79349381, 179.14904646,
#        160.5437159 , 163.39446127, 168.12565235, 167.2979112 ,
#        160.82526767, 166.74062109, 152.84715194, 196.8689645 ,
#        175.57193408, 159.65346871, 151.13090962, 166.52214631,
#        157.96202927, 169.35100905, 157.61342866, 154.60218804,
#        169.85258073, 154.62788267, 152.52381311, 171.9886309 ,
#        182.47151583, 164.48171803, 165.74421254, 144.30301973,
#        165.2067183 , 181.55228487, 169.98085661, 161.97785743,
#        176.19166779, 156.89966766, 178.0147689 , 169.1980911 ,
#        165.68869223, 144.71844611, 181.23932883, 186.79359142,
#        184.58680751, 159.85361204, 173.37292351, 172.79419516,
#        160.46038249, 174.92966357, 187.57105804, 159.58582579,
#        174.90752122, 183.7032206 , 176.72147608, 171.39402161,
#        182.21061599, 168.31557493, 178.63016753, 181.17450786,
#        177.98547044, 188.34461919, 184.51352936, 160.73616266,
#        183.38678628, 175.60524386, 173.00162901, 162.39394901,
#        175.39292059, 174.69996335, 156.35955648, 138.05348022,
#        154.14892519, 156.67947334, 173.55216458, 183.7325158 ,
#        157.42788786, 164.1783095 , 162.25360108, 182.02820081,
#        177.31261271, 167.62197278, 175.82716991, 166.62005797,
#        164.2868255 , 159.70274206, 201.33433184, 173.20026387,
#        169.98398452, 171.14191657, 175.73439305, 173.73090986,
#        175.24894526, 162.63234635, 163.30906223, 164.86005812,
#        158.00226281, 177.75543873, 170.39453581, 165.06218321,
#        146.97413764, 168.26953481, 163.66789016, 147.69861811,
#        163.86635496, 159.03582669, 184.49714367, 169.65918888,
#        165.83474896, 152.12229088, 154.51987085, 164.65169858,
#        175.52788908, 154.50632041, 170.69956794, 159.75549603,
#        165.08340756, 146.58179762, 186.88767805, 164.20531218,
#        176.64880585, 170.88818769, 190.25381043, 160.86089688,
#        167.78035173, 170.18406442, 182.65507455, 175.30824485,
#        165.28084215, 173.16177865, 184.21599252, 171.63940654,
#        179.00539774, 164.47904025, 156.57080317, 165.16575741,
#        165.25806149, 164.61334136, 171.43734037, 171.26866878,
#        161.10936112, 162.89394696, 146.59337543, 159.12357747,
#        164.57285288, 159.62042137, 151.40746218, 170.99727223,
#        168.29058789, 176.98267172, 174.83810739, 160.67461475,
#        170.17177608, 161.8728566 , 171.19908293, 178.49203999,
#        179.3691189 , 178.11844082, 181.88529767, 168.7130316 ,
#        161.13347794, 185.89375089, 173.54760037, 168.32558123,
#        165.26105299, 161.41280301, 182.28629118, 155.98678172,
#        168.63038708, 165.1184069 , 146.74657283, 162.81153839,
#        172.97529331, 172.44667226, 157.8112706 , 173.8208247 ,
#        171.79300949, 181.33286065, 161.49718076, 170.96847046,
#        179.02915701, 163.92922323, 172.02356776, 184.0901664 ,
#        191.28206252, 186.19210695, 178.90825626, 183.63908017,
#        161.69074187, 172.28629978, 180.24889442, 166.28838153,
#        170.20755884, 172.91083477, 168.61914214, 182.69127363,
#        183.17272834, 166.4675565 , 179.08433181, 182.40371621,
#        170.14316077, 154.03923409, 156.17539574, 174.4375003 ,
#        192.6429352 , 177.61707958, 172.49252794, 165.07985771,
#        172.84091953, 159.8697757 , 183.74379289, 168.64211384,
#        199.16703491, 172.26012388, 174.55289731, 177.0256299 ,
#        161.1107366 , 169.92369764, 172.89771845, 171.5530957 ,
#        170.814475  , 161.44765777, 174.03340008, 165.93726369,
#        165.67004086, 175.43319106, 171.26528969, 151.0059411 ,
#        171.87288894, 167.63794193, 157.69687521, 167.44436234,
#        166.2542027 , 179.32862832])

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# #pie

# %%
x=np.array([1,2,3,4])
plt.pie(x)
plt.show()

# %%
x=np.array([1,2,3,4])

#np.array({})
labels =["apple","bannn","cherries","dates"]
myexplode=[0,0.2,0,0]

plt.pie(x,labels=labels,explode=myexplode)
plt.show()

# %%
x=np.array([1,2,3,4])

#np.array({})
labels =["apple","bannana","cherries","dates"]
myexplode=[0,0.2,0,0]

plt.pie(x,labels=labels,explode=myexplode,startangle=90,shadow=True,colors=c)
plt.show()

# %%
x=np.array([1,2,3,4])

#np.array({})
labels =["apple","bannana","cherries","dates"]
myexplode=[0,0.2,0,0]

plt.pie(x,labels=labels,explode=myexplode,startangle=90,shadow=True,colors=c,autopct='%1.1f%%')
plt.legend(title="my pie chart")
plt.show()
