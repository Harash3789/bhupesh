# %% [markdown]
# # Function
# ## user define function
# ## pre define function

# %%
def function_name():
    pass
# function_name>>>>>>>>>..function name
# def is keyword
# pass>>>placeholder

# %%
def function_name():
    pass
# function_name>>>>>>>>>..function name
# def is keyword
# pass >>> placeholder
function_name()#>>>calling function

# %%
def display():
    print("hello")

# %%
display()
# Out:
# hello

# %%
def add():
    a=10 
    b=20
    print(a+b)
    add()

# %%
add()
# Out:
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# ...

# %%
def add(a,b):
    print (a+b)
    
add (a=10,b=20)
# Out:
# 30

# %%
def display(name, age, address="jaipur"):
    print(f"my name is {name}and my {age}and my {address}")

# %%
display("ritik",22)
# Out:
# my name is ritikand my 22and my jaipur

# %%
# lamda function
# lambda >>>keyword
# lamda is a anomyousfunction
#  is used for single line function
# it is used for sort function
# it is used for one line functionit
