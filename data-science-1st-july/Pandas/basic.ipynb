# %% [markdown]
# * Pandas is a powerful and easy-to-use data analysis and manipulation library for Python. It is especially useful when working with structured data (like tables, Excel files, or SQL results).
#
#
# | Feature                 | Description                                                     |
# | ----------------------- | --------------------------------------------------------------- |
# | *DataFrame & Series*  | Core data structures to store tabular and one-dimensional data. |
# | *Read/Write Files*    | Load data from CSV, Excel, SQL, JSON, etc.                      |
# | *Data Cleaning*       | Handle missing values, remove duplicates, filter rows.          |
# | *Data Manipulation*   | Merge, join, group, sort, pivot, and reshape data.              |
# | *Statistics*          | Built-in functions like mean, median, standard deviation.       |
# | *Time Series Support* | Great tools for handling date and time data.                    |

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df =pd.read_csv('used_bikes.csv')

# %%
df = pd.read_csv(r"C:\Users\harsh\OneDrive\Desktop\data science\Pandas\Used_Bikes.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\harsh\OneDrive\Desktop\data science\Pandas\Used_Bikes.csv")
#
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.info()#### data set ki information nikal ke deta hai
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0    bike_name  32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               price     kms_driven          age        power
# count  7.324000e+03    7324.000000  7324.000000  7324.000000
# mean   8.488390e+04   23910.496587     6.656472   228.133397
# std    1.209662e+05   27317.594631     3.605299   158.324219
# min    4.400000e+03       1.000000     1.000000   100.000000
# 25%    3.000000e+04   10155.750000     4.000000   125.000000
# 50%    5.500000e+04   19000.000000     6.000000   160.000000
# 75%    1.000000e+05   30112.000000     8.000000   350.000000
# max    1.900000e+06  750000.000000    63.000000  1800.000000

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail()
# Out:
#                            bike_name     price       city  kms_driven  \
# 9362       Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369             Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370  Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371           Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372        Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# 9362  First Owner  8.0  150.0             Hero
# 9369  First Owner  9.0  220.0            Bajaj
# 9370  First Owner  4.0  750.0  Harley-Davidson
# 9371  First Owner  4.0  400.0            Bajaj
# 9372  First Owner  5.0  220.0            Bajaj

# %%
df.tail(10)#### lower  value
# Out:
#                            bike_name     price       city  kms_driven  \
# 9348                  KTM Duke 390cc  195000.0     Mumbai      4568.0
# 9349             Bajaj Pulsar  180cc   55000.0       Pune     10000.0
# 9350              Bajaj Pulsar NS200   46000.0  Bangalore     27687.0
# 9360              Bajaj Pulsar NS200   48000.0  Allahabad     41939.0
# 9361             Bajaj Avenger 220cc   50000.0  Bangalore     29134.0
# 9362       Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369             Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370  Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371           Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372        Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# 9348  First Owner  4.0  390.0              KTM
# 9349  First Owner  6.0  180.0            Bajaj
# 9350  Third Owner  9.0  200.0            Bajaj
# ...

# %%
df.columns
# Out:
# Index([' bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.brand
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7324, dtype: object

# %%
df.price
# Out:
# 0        35000.0
# 1       119900.0
# 2       600000.0
# 3        65000.0
# 4        80000.0
#           ...
# 9362     25000.0
# 9369     35000.0
# 9370    450000.0
# 9371    139000.0
# 9372     80000.0
# Name: price, Length: 7324, dtype: float64

# %%
df.brand
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7324, dtype: object

# %%
df['brand']
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7324, dtype: object

# %%
df['owner']
# Out:
# 0       First Owner
# 1       First Owner
# 2       First Owner
# 3       First Owner
# 4       First Owner
#            ...
# 9362    First Owner
# 9369    First Owner
# 9370    First Owner
# 9371    First Owner
# 9372    First Owner
# Name: owner, Length: 7324, dtype: object

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
df["brand"].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
df['brand'].unique()####show unique brand name
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['brand'].nunique()
# Out:
# 23

# %%
df.shape
# Out:
# (7324, 8)

# %%
df.dtypes
# Out:
#  bike_name     object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
# brand = royal enfield
# age=2 se km
# km = 50000

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
royal_df=df[df['brand']=='Royal Enfield']

# %%
royal_df
# Out:
#                                      bike_name     price       city  \
# 1                  Royal Enfield Classic 350cc  119900.0      Delhi
# 8            Royal Enfield Thunderbird X 350cc  145000.0  Bangalore
# 9     Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi
# 23          Royal Enfield Classic Chrome 500cc  121700.0     Kalyan
# 36                 Royal Enfield Classic 350cc   98800.0      Kochi
# ...                                        ...       ...        ...
# 9261               Royal Enfield Classic 500cc  146006.0   Guwahati
# 9319               Royal Enfield Classic 350cc  100000.0    Chennai
# 9337             Royal Enfield Himalayan 410cc  120000.0    Gurgaon
# 9338             Royal Enfield Himalayan 410cc  138000.0      Delhi
# 9344      Royal Enfield Bullet Twinspark 350cc   80000.0      Delhi
#
#       kms_driven         owner   age  power          brand
# 1        11000.0   First Owner   4.0  350.0  Royal Enfield
# ...

# %%
royal_df_age = royal_df[royal_df['age']==2]

# %%
royal_df_age
# Out:
#                                          bike_name     price          city  \
# 38               Royal Enfield Thunderbird X 500cc  190500.0    Samastipur
# 81                 Royal Enfield Interceptor 650cc  260000.0   Navi Mumbai
# 139           Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 194                    Royal Enfield Electra 350cc  145000.0     Bangalore
# 222           Royal Enfield Himalayan 410cc Fi ABS  177982.0  Hamirpur(hp)
# ...                                            ...       ...           ...
# 7294  Royal Enfield Classic 350cc-Redditch Edition  133500.0        Mumbai
# 7694        Royal Enfield Classic Chrome 500cc ABS  215000.0         Delhi
# 8139         Royal Enfield Thunderbird X 350cc ABS  169000.0     Bangalore
# 8192           Royal Enfield Thunderbird 350cc ABS  145000.0     Ghaziabad
# 8836         Royal Enfield Thunderbird X 350cc ABS  170200.0        Mumbai
#
#       kms_driven        owner  age  power          brand
# ...

# %%
royal_df_age_km = royal_df_age[royal_df_age['kms_driven'] <=50000]

# %%
royal_df_age_km
# Out:
#                                          bike_name     price          city  \
# 38               Royal Enfield Thunderbird X 500cc  190500.0    Samastipur
# 81                 Royal Enfield Interceptor 650cc  260000.0   Navi Mumbai
# 139           Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 194                    Royal Enfield Electra 350cc  145000.0     Bangalore
# 222           Royal Enfield Himalayan 410cc Fi ABS  177982.0  Hamirpur(hp)
# ...                                            ...       ...           ...
# 7294  Royal Enfield Classic 350cc-Redditch Edition  133500.0        Mumbai
# 7694        Royal Enfield Classic Chrome 500cc ABS  215000.0         Delhi
# 8139         Royal Enfield Thunderbird X 350cc ABS  169000.0     Bangalore
# 8192           Royal Enfield Thunderbird 350cc ABS  145000.0     Ghaziabad
# 8836         Royal Enfield Thunderbird X 350cc ABS  170200.0        Mumbai
#
#       kms_driven        owner  age  power          brand
# ...

# %%
# brand= tvs
# age = 2 se km
# price <= 40000
# owner ='lst owner'
# km driven <=40000

# %%
df.query(' brand == "TVS" and age ==2 and price <= 100000 and owner == "First Owner" and kms_driven <=40000')
# Out:
#                                               bike_name    price  \
# 193                  TVS Apache RTR 160 4V DISC ABS BS6  85000.0
# 360                          TVS Apache RTR 160 4V Disc  78700.0
# 425                      TVS Apache RTR 160 4V DISC ABS  87000.0
# 511                      TVS Apache RTR 160 4V DRUM ABS  85000.0
# 594                      TVS Apache RTR 160 4V DISC ABS  91800.0
# 664                      TVS Apache RTR 160 4V DISC ABS  89000.0
# 757                          TVS Apache RTR 160 4V Disc  74700.0
# 1097  TVS Apache RTR 200 4V Carburetor Race Edition 2.0  93500.0
# 1514            TVS Apache RTR 160cc Matt Red Rear Disc  76000.0
# 1741  TVS Apache RTR 200 4V Carburetor Pirelli Tyres...  98500.0
# 1762                     TVS Apache RTR 160 4V DISC ABS  89135.0
# 1802                               TVS Apache RTR 180cc  88000.0
# 2325                          TVS Apache RTR 200 4V ABS  92000.0
# ...

# %%
royal_df =df[
    (df['brand']=='Royal Enfield')&
    (df['kms_driven']==30000)&
    (df['owner']=='First Owner')&
    (df['price']<=100000)]

# %%
royal_df
# Out:
#                                bike_name     price     city  kms_driven  \
# 1311         Royal Enfield Classic 350cc   80000.0     Pune     30000.0
# 3783  Royal Enfield Bullet Electra 350cc   65000.0    Delhi     30000.0
# 5593     Royal Enfield Thunderbird 350cc   75000.0  Chennai     30000.0
# 6485     Royal Enfield Thunderbird 350cc   70000.0    Delhi     30000.0
# 6716         Royal Enfield Classic 350cc  100000.0  Chennai     30000.0
# 6719  Royal Enfield Bullet Electra 350cc   75000.0    Delhi     30000.0
# 7716         Royal Enfield Classic 350cc  100000.0    Delhi     30000.0
# 8012     Royal Enfield Thunderbird 350cc   75000.0     Pune     30000.0
#
#             owner   age  power          brand
# 1311  First Owner   5.0  350.0  Royal Enfield
# 3783  First Owner  11.0  350.0  Royal Enfield
# 5593  First Owner  10.0  350.0  Royal Enfield
# 6485  First Owner  11.0  350.0  Royal Enfield
# 6716  First Owner   5.0  350.0  Royal Enfield
# ...

# %%
df.query('brand=="Royal Enfield" and kms_driven <=30000 and owner == "First Owner"and price<=100000')
# Out:
#                                bike_name     price       city  kms_driven  \
# 42    Royal Enfield Bullet Electra 350cc   78000.0    Lucknow      8500.0
# 44           Royal Enfield Classic 350cc   85000.0      Delhi     18000.0
# 51           Royal Enfield‎ Bullet 350cc   90000.0      Delhi     15300.0
# 64       Royal Enfield Thunderbird 350cc   88000.0      Delhi     19000.0
# 72       Royal Enfield Thunderbird 350cc   65000.0  Jalandhar      9800.0
# ...                                  ...       ...        ...         ...
# 9181  Royal Enfield Bullet Electra 350cc   60350.0      Delhi     26381.0
# 9197         Royal Enfield Classic 350cc   90000.0     Jaipur     17000.0
# 9236     Royal Enfield Thunderbird 350cc   95000.0      Surat     22000.0
# 9252         Royal Enfield Classic 350cc  100000.0  Ghaziabad     15078.0
# 9319         Royal Enfield Classic 350cc  100000.0    Chennai     25000.0
#
#             owner   age  power          brand
# ...

# %%
df.rename
# Out:
# <bound method DataFrame.rename of                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.drop(['bike_name','city'],axis=1,inplace=True)

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.to_csv('used_bikes_cleaned.csv',index=False)

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
char=df.select_dtypes(include='object')

# %%
char
# Out:
#                                   bike_name       city        owner  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1               Royal Enfield Classic 350cc      Delhi  First Owner
# 2                      Triumph Daytona 675R      Delhi  First Owner
# 3                      TVS Apache RTR 180cc  Bangalore  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                     ...        ...          ...
# 32643                Hero Passion Pro 100cc      Delhi  First Owner
# 32644                  TVS Apache RTR 180cc     Karnal  First Owner
# 32645              Bajaj Avenger Street 220      Delhi  First Owner
# 32646             Hero Super Splendor 125cc     Jaipur  First Owner
# 32647                    Bajaj Pulsar 150cc       Pune  First Owner
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...

# %%
nun=df.select_dtypes(exclude='object')

# %%
nun
# Out:
#           price  kms_driven   age  power
# 0       35000.0     17654.0   3.0  110.0
# 1      119900.0     11000.0   4.0  350.0
# 2      600000.0       110.0   8.0  675.0
# 3       65000.0     16329.0   4.0  180.0
# 4       80000.0     10000.0   3.0  150.0
# ...         ...         ...   ...    ...
# 32643   39000.0     22000.0   4.0  100.0
# 32644   30000.0      6639.0   9.0  180.0
# 32645   60000.0     20373.0   6.0  220.0
# 32646   15600.0     84186.0  16.0  125.0
# 32647   22000.0     60857.0  13.0  150.0
#
# [32648 rows x 4 columns]

# %%
char['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
owner_dict ={
    'first owner':1,
    'second ownwer':2,
    'third owner':3,
    'fourth owner ormore':4
}

# %%
char['owner']=char['owner'].map(owner_dict)

# %%
char['owner'].unique()
# Out:
# array([nan])

# %%
char['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=labelEncoder()

char['brand']=le.fit_transform(char['brand'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 from sklearn.preprocessing import LabelEncoder
# ----> 2 le=labelEncoder()
#       4 char['brand']=le.fit_transform(char['brand'])
#
# NameError: name 'labelEncoder' is not defined

# %%
char
# Out:
#                                   bike_name       city  owner          brand
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad    NaN            TVS
# 1               Royal Enfield Classic 350cc      Delhi    NaN  Royal Enfield
# 2                      Triumph Daytona 675R      Delhi    NaN        Triumph
# 3                      TVS Apache RTR 180cc  Bangalore    NaN            TVS
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore    NaN         Yamaha
# ...                                     ...        ...    ...            ...
# 32643                Hero Passion Pro 100cc      Delhi    NaN           Hero
# 32644                  TVS Apache RTR 180cc     Karnal    NaN            TVS
# 32645              Bajaj Avenger Street 220      Delhi    NaN          Bajaj
# 32646             Hero Super Splendor 125cc     Jaipur    NaN           Hero
# 32647                    Bajaj Pulsar 150cc       Pune    NaN          Bajaj
#
# [32648 rows x 4 columns]

# %%
char
# Out:
#                                   bike_name       city  owner          brand
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad    NaN            TVS
# 1               Royal Enfield Classic 350cc      Delhi    NaN  Royal Enfield
# 2                      Triumph Daytona 675R      Delhi    NaN        Triumph
# 3                      TVS Apache RTR 180cc  Bangalore    NaN            TVS
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore    NaN         Yamaha
# ...                                     ...        ...    ...            ...
# 32643                Hero Passion Pro 100cc      Delhi    NaN           Hero
# 32644                  TVS Apache RTR 180cc     Karnal    NaN            TVS
# 32645              Bajaj Avenger Street 220      Delhi    NaN          Bajaj
# 32646             Hero Super Splendor 125cc     Jaipur    NaN           Hero
# 32647                    Bajaj Pulsar 150cc       Pune    NaN          Bajaj
#
# [32648 rows x 4 columns]

# %%
clean_data=pd.concat([char,nun],axis=1)

# %%
clean_data
# Out:
#                                   bike_name       city  owner          brand  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad    NaN            TVS
# 1               Royal Enfield Classic 350cc      Delhi    NaN  Royal Enfield
# 2                      Triumph Daytona 675R      Delhi    NaN        Triumph
# 3                      TVS Apache RTR 180cc  Bangalore    NaN            TVS
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore    NaN         Yamaha
# ...                                     ...        ...    ...            ...
# 32643                Hero Passion Pro 100cc      Delhi    NaN           Hero
# 32644                  TVS Apache RTR 180cc     Karnal    NaN            TVS
# 32645              Bajaj Avenger Street 220      Delhi    NaN          Bajaj
# 32646             Hero Super Splendor 125cc     Jaipur    NaN           Hero
# 32647                    Bajaj Pulsar 150cc       Pune    NaN          Bajaj
#
#           price  kms_driven   age  power
# ...
